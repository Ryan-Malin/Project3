# %% [markdown]
# ### Health Categories

# %%
health_categories = [
#     'fips', 'state', 'county', 'lat', 'lon',
    'average_number_of_physically_unhealthy_days',
    'average_number_of_mentally_unhealthy_days',
    'percent_adults_with_obesity',
    'percent_physically_inactive',
    'percent_with_access_to_exercise_opportunities',
    'percent_excessive_drinking',
    'percent_driving_deaths_with_alcohol_involvement',
    'primary_care_physicians_rate',
    'mental_health_provider_rate',
    'preventable_hospitalization_rate',
    'presence_of_water_violation',
    'percent_frequent_physical_distress',
    'percent_frequent_mental_distress',
    'percent_insufficient_sleep',
    'percent_uninsured',
    'percent_uninsured_2',
    'other_primary_care_provider_rate',
    'suicide_rate_age_adjusted'
]

# %% [markdown]
# ### Economic Categories

# %%
economic_categories = [
#     'fips', 'state', 'county', 'lat', 'lon',
    'percent_children_in_poverty',
    'eightieth_percentile_income',
    'median_household_income',
    'twentieth_percentile_income',
    'percent_severe_housing_problems',
    'overcrowding',
    'inadequate_facilities',
    'percent_food_insecure',
    'percent_limited_access_to_healthy_foods',
    'percent_enrolled_in_free_or_reduced_lunch',
    'percent_homeowners',
    'percent_severe_housing_cost_burden',
    'percent_below_poverty',
    'percent_unemployed_CDC',
    'percent_overcrowding'
]

# %% [markdown]
# ### Others

# %%
# [
#     'percent_smokers',
#     'percent_adults_with_diabetes',
#     'percent_drive_alone_to_work',
#     'percent_long_commute_drives_alone',
#     'hiv_prevalence_rate',
#     'average_traffic_volume_per_meter_of_major_roadways',
#     'age_adjusted_death_rate',
#     'child_mortality_rate',
#     'infant_mortality_rate',
#     'percent_less_than_18_years_of_age',
#     'percent_65_and_over',
#     'percent_single_parent_households_CDC',
#     'percent_no_vehicle',
#     'percent_institutionalized_in_group_quarters',
# ]

# %%
import pandas as pd

# %%
df = pd.read_csv("../us_county_sociohealth_data.csv")

# %%
health_df = df[health_categories]
economy_df = df[economic_categories]

# %%
health_df.describe()
# Out:
#        average_number_of_physically_unhealthy_days  \
# count                                  3144.000000
# mean                                      3.990334
# std                                       0.704652
# min                                       2.449054
# 25%                                       3.471602
# 50%                                       3.936297
# 75%                                       4.440838
# max                                       7.062310
#
#        average_number_of_mentally_unhealthy_days  percent_adults_with_obesity  \
# count                                3144.000000                  3144.000000
# mean                                    4.167264                    32.853657
# std                                     0.602526                     5.453932
# min                                     2.532818                    12.400000
# 25%                                     3.748762                    29.200000
# 50%                                     4.172891                    33.100000
# 75%                                     4.575163                    36.500000
# max                                     6.313753                    57.700000
#
#        percent_physically_inactive  \
# count                  3144.000000
# mean                     27.365692
# std                       5.695856
# min                       9.500000
# 25%                      23.500000
# 50%                      27.200000
# 75%                      31.025000
# max                      49.900000
#
#        percent_with_access_to_exercise_opportunities  \
# count                                    3138.000000
# mean                                       62.834015
# std                                        23.372086
# min                                         0.000000
# 25%                                        48.519960
# 50%                                        65.884882
# 75%                                        80.174883
# max                                       100.000000
#
#        percent_excessive_drinking  \
# count                 3144.000000
# mean                    17.513798
# std                      3.148348
# min                      7.809632
# 25%                     15.295852
# 50%                     17.573243
# 75%                     19.672265
# max                     28.623739
#
#        percent_driving_deaths_with_alcohol_involvement  \
# count                                      3109.000000
# mean                                         28.325433
# std                                          15.018175
# min                                           0.000000
# 25%                                          19.607843
# 50%                                          27.500000
# 75%                                          35.483871
# max                                         100.000000
#
#        primary_care_physicians_rate  mental_health_provider_rate  \
# count                   2997.000000                  2914.000000
# mean                      54.522473                   160.844534
# std                       35.270663                   173.328812
# min                        0.000000                     0.000000
# 25%                       31.898850                    48.209035
# 50%                       48.350050                   112.056925
# 75%                       70.827800                   214.620605
# max                      514.448340                  2212.340800
#
#        preventable_hospitalization_rate  percent_frequent_physical_distress  \
# count                       3101.000000                         3144.000000
# mean                        4858.344743                           12.132718
# std                         1841.024406                            2.338947
# min                          536.000000                            7.150455
# 25%                         3619.000000                           10.354321
# 50%                         4710.000000                           11.879275
# 75%                         5801.000000                           13.591546
# max                        16851.000000                           24.129678
#
#        percent_frequent_mental_distress  percent_insufficient_sleep  \
# count                       3144.000000                 3144.000000
# mean                          12.995423                   33.045109
# std                            1.976249                    4.156910
# min                            8.003231                   23.028348
# 25%                           11.551372                   30.023276
# 50%                           12.933357                   32.951929
# 75%                           14.309341                   36.114139
# max                           21.247813                   46.707783
#
#        percent_uninsured  percent_uninsured_2  \
# count        3143.000000          3143.000000
# mean           11.476161            13.585495
# std             5.143456             6.220829
# min             2.262724             2.682596
# 25%             7.395900             8.565021
# 50%            10.559006            12.489258
# 75%            14.473529            17.392735
# max            33.749600            42.397495
#
#        other_primary_care_provider_rate  suicide_rate_age_adjusted
# count                       3122.000000                2381.000000
# mean                          84.967508                  18.412745
# std                           62.432786                   7.732379
# min                            0.000000                   5.115770
# 25%                           49.590442                  13.739880
# 50%                           72.975165                  17.167171
# 75%                          105.290923                  21.235679
# max                         1557.017540                 118.974198

# %%
economy_df.describe()
# Out:
#        percent_children_in_poverty  eightieth_percentile_income  \
# count                  3143.000000                  3142.000000
# mean                     21.105737                 98424.009911
# std                       8.900554                 22811.801631
# min                       2.500000                 48123.000000
# 25%                      14.500000                 83754.250000
# 50%                      20.100000                 94420.500000
# 75%                      26.300000                106731.500000
# max                      68.300000                236506.000000
#
#        median_household_income  twentieth_percentile_income  \
# count              3143.000000                  3142.000000
# mean              52803.609553                 22521.061206
# std               13881.051537                  6742.082154
# min               25385.000000                  5756.000000
# 25%               43684.500000                 17995.500000
# 50%               50576.000000                 21675.000000
# 75%               58858.500000                 25810.500000
# max              140382.000000                 64399.000000
#
#        percent_severe_housing_problems  overcrowding  inadequate_facilities  \
# count                      3144.000000   3144.000000            3144.000000
# mean                         13.874050      2.422426               1.220661
# std                           4.581798      2.415194               1.657181
# min                           3.220339      0.000000               0.000000
# 25%                          11.008520      1.233838               0.631025
# 50%                          13.333333      1.887441               0.939858
# 75%                          15.922820      2.852010               1.420455
# max                          70.893372     51.585014              37.373737
#
#        percent_food_insecure  percent_limited_access_to_healthy_foods  \
# count            3144.000000                              3125.000000
# mean               13.250693                                 8.648033
# std                 3.959159                                 8.367483
# min                 2.900000                                 0.000000
# 25%                10.600000                                 3.624300
# 50%                12.800000                                 6.508531
# 75%                15.200000                                10.672981
# max                36.300000                                71.844209
#
#        percent_enrolled_in_free_or_reduced_lunch  percent_homeowners  \
# count                                3022.000000         3144.000000
# mean                                   53.912894           71.419818
# std                                    18.637979            8.282220
# min                                     0.000000            4.255319
# 25%                                    41.231414           67.544582
# 50%                                    52.464072           72.621625
# 75%                                    64.069369           77.036332
# max                                   100.000000           92.396814
#
#        percent_severe_housing_cost_burden  percent_below_poverty  \
# count                         3140.000000            3144.000000
# mean                            11.269022              16.407221
# std                              3.596751               6.551979
# min                              0.900901               1.800000
# 25%                              8.866359              11.700000
# 50%                             10.826548              15.600000
# 75%                             13.241565              19.900000
# max                             31.661797              53.900000
#
#        percent_unemployed_CDC  percent_overcrowding
# count             3144.000000           3144.000000
# mean                 7.090189              2.419351
# std                  3.297000              2.416937
# min                  0.000000              0.000000
# 25%                  4.975000              1.200000
# 50%                  6.800000              1.900000
# 75%                  8.800000              2.800000
# max                 29.900000             51.400000

# %%
health_df.to_json("health_index.json", orient = "index")
economy_df.to_json("economy_index.json", orient = "index")

# %%
health_df.to_json("health.json")
economy_df.to_json("economy.json")
