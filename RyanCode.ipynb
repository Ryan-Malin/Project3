# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
raw_data = "us_county_sociohealth_data.csv"

# %%
raw_data_df = pd.read_csv(raw_data)

# %%
raw_data_df.dropna()
raw_data_df.head()
raw_data_df = raw_data_df[(raw_data_df["state"] == "North Carolina")]

# %%
raw_data_df[["percent_limited_access_to_healthy_foods","percent_adults_with_diabetes","high_school_graduation_rate","teen_birth_rate","percent_fair_or_poor_health"]].sort_values("high_school_graduation_rate", ascending=True).head()
# Out:
#       percent_limited_access_to_healthy_foods  percent_adults_with_diabetes  \
# 1955                                 7.065273                          21.9
# 1948                                 1.370306                          13.0
# 1982                                 4.255596                           7.1
# 1983                                12.945299                          17.5
# 1931                                 9.386242                          22.2
#
#       high_school_graduation_rate  teen_birth_rate  \
# 1955                    63.400000        40.844298
# 1948                    69.500000        32.790353
# 1982                    71.300000        33.969680
# 1983                    72.500000        38.099140
# 1931                    75.473477        41.896362
#
#       percent_fair_or_poor_health
# 1955                    23.455465
# 1948                    21.712093
# 1982                    22.941932
# 1983                    23.914690
# ...

# %%
plt.scatter(raw_data_df["percent_fair_or_poor_health"],
            raw_data_df["high_school_graduation_rate"])

# %%
plt.scatter(raw_data_df["percent_adults_with_diabetes"],
            raw_data_df["high_school_graduation_rate"])

# %%
plt.scatter(raw_data_df["percent_adults_with_diabetes"],
            raw_data_df["percent_limited_access_to_healthy_foods"])

# %%
plt.scatter(raw_data_df["percent_adults_with_diabetes"],
            raw_data_df["percent_limited_access_to_healthy_foods"])

# %%
plt.scatter(raw_data_df["teen_birth_rate"],
            raw_data_df["percent_limited_access_to_healthy_foods"])

# %%
plt.scatter(raw_data_df["teen_birth_rate"],
            raw_data_df["percent_unemployed_CHR"])

# %%
plt.scatter(raw_data_df["percent_physically_inactive"],
            raw_data_df["percent_adults_with_obesity"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["percent_fair_or_poor_health"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["percent_physically_inactive"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["percent_excessive_drinking"])

# %%
plt.scatter(raw_data_df["percent_physically_inactive"],
            raw_data_df["life_expectancy"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["life_expectancy"])

# %%
plt.scatter(raw_data_df["percent_below_poverty"],
            raw_data_df["average_number_of_mentally_unhealthy_days"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["eightieth_percentile_income"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["percent_single_parent_households_CHR"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["life_expectancy"])

# %%
plt.scatter(raw_data_df["percent_fair_or_poor_health"],
            raw_data_df["percent_smokers"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["percent_frequent_physical_distress"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["percent_food_insecure"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["percent_insufficient_sleep"])

# %%
plt.scatter(raw_data_df["average_number_of_mentally_unhealthy_days"],
            raw_data_df["homicide_rate"])

# %%
plt.scatter(raw_data_df["__"],
            raw_data_df["__"])

# %%
plt.scatter(raw_data_df["__"],
            raw_data_df["__"])

# %%
plt.scatter(raw_data_df["__"],
            raw_data_df["__"])

# %%
plt.scatter(raw_data_df["__"],
            raw_data_df["__"])

# %%
plt.scatter(raw_data_df["__"],
            raw_data_df["__"])

# %%
plt.scatter(raw_data_df["__"],
            raw_data_df["__"])

# %%
plt.scatter(raw_data_df["__"],
            raw_data_df["__"])
